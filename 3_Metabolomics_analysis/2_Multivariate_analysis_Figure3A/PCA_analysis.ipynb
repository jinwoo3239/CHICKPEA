# %%
import pandas as pd

from libs.utils_multivariate import MultiVariateAnalysis

import warnings
warnings.filterwarnings('ignore')

# %%
multi_analysis= MultiVariateAnalysis(n_components=5, is_save_file=False, dpi=600)

# %%
df = pd.read_csv('./data/data_normalized.csv')
df.head()
# Out:
#   Name     Label  0.958_138.05499  1.703_230.11353  14.279_441.37311  \
# 0  S11  Chickpea         0.870813        -0.182798          1.247243
# 1  S12  Chickpea         0.829451        -0.026670          1.206856
# 2  S13  Chickpea         1.003965        -0.336993          1.320390
# 3  S14  Chickpea         0.840697         0.038199          0.412090
# 4  S15  Chickpea         0.817451        -0.310686          0.960571
#
#    1.131_136.0618  1.176_130.08625  0.996_246.18116  11.383_279.23189  \
# 0        1.064390         0.550279         0.875742          0.222416
# 1        0.645036         0.190455         1.009040          0.025550
# 2        0.361997         0.027539         0.773438         -0.329642
# 3        1.029287         0.868446        -0.413892         -0.644741
# 4        0.562749         0.383045         0.417334          0.009327
#
#    12.839_339.25073  ...  0.938_118.051  6.746_131.07141  1.294_128.03537  \
# 0          0.172190  ...       0.384400        -0.760333        -0.977235
# 1          0.338661  ...       0.678662         1.481281         1.346128
# 2         -0.014383  ...       0.552838        -0.194493         0.097543
# 3          0.887726  ...       0.046444        -1.904714         0.195132
# 4          0.384619  ...      -0.001227        -0.674742         1.232178
#
#    7.241_165.05576  12.26_437.2912  11.571_309.17089  1.229_148.04383  \
# 0        -0.728170       -0.464622         -0.300317         0.416187
# 1         1.114358        0.795156          0.701683         0.219991
# 2         0.874493        0.853722          0.419594         0.427670
# 3        -0.901683       -1.422031         -0.638577         0.049840
# 4        -0.889534       -1.065174          0.368178        -0.127582
#
#    1.291_243.06234  1.218_142.05102  1.231_202.07271
# 0        -0.045913        -0.215675        -1.558291
# 1        -0.201854        -0.299723        -1.016032
# 2        -0.209519         0.051878         1.089248
# 3         0.652739        -0.617524        -0.901698
# 4        -0.517115        -0.415685         0.831279
#
# [5 rows x 232 columns]

# %%
# Figure 2A, two group, PLS-DA analysis, positive
print('total')
_ = multi_analysis.pca_analysis(df, palette=['lightseagreen', 'lightcoral'], figsize=(2.7, 2.5), marker_size=50)
# Out:
# total
