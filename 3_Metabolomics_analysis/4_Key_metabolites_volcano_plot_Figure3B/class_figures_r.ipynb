# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Arial'

import warnings
warnings.filterwarnings("ignore")

# %%
# orders = ['Control', 'Chickpea']
# g_colors = ['lightcoral', 'lightseagreen']

# %%
file_path = './data/Key_metabolites.xlsx'

df = pd.read_excel(file_path, sheet_name='id')

# %%
source_counts = df['Putative source'].value_counts()


source_color_map = {
    'Metabolic intermediate': '#f8766d',
    'Native phytochemical': '#64b5f6',
    'Hydrolysis product': '#7cae00',
    np.nan: 'lightgray'
}

colors = ['#f8766d','#64b5f6', '#81c784',]

plt.figure(figsize=(3.3, 1.5))
# plt.figure(figsize=(8, 5))
sns.barplot(y=source_counts.index, x=source_counts.values, palette=colors)
# plt.title('Number of Metabolites by Putative Source')
# plt.xlabel('Count')
plt.ylabel('')
plt.xticks([0, 2, 4, 6, 8, 10, 12], fontsize=9)
plt.yticks(fontsize=9)

plt.tight_layout()
plt.savefig('source_class.png', dpi=600)

plt.show()

# %%
class_counts = df['Class'].value_counts()

labels = class_counts.index
sizes = class_counts.values


explode = [0.05] * len(sizes)  # 모든 조각을 0.03만큼 띄움


colors = sns.color_palette("Set3", n_colors=len(labels))
plt.figure(figsize=(6, 6))
wedges, texts, autotexts = plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    explode=explode,
    colors=colors,
    wedgeprops={'linewidth': 0}
)


plt.title('Proportion of Metabolites by Class')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Re-import necessary packages due to kernel reset
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
file_path = './data/Key_metabolites.xlsx'

df = pd.read_excel(file_path, sheet_name='Sheet2')


# 데이터 준비
class_counts = df['Class'].value_counts()
labels = class_counts.index
sizes = class_counts.values
explode = [0.03] * len(sizes)
colors = sns.color_palette("Set3", n_colors=len(labels))

# 파이차트 그리기 (autotext 제거 → 수동 배치할 예정)
plt.figure(figsize=(4, 2.5))
wedges, texts = plt.pie(
    sizes,
    labels=labels,
    startangle=75,
    explode=explode,
    colors=colors,
    wedgeprops={'linewidth': 0},
      textprops={'fontsize': 9}
)

# 퍼센트 수동 배치
total = sum(sizes)
for i, (wedge, size) in enumerate(zip(wedges, sizes)):
    angle = (wedge.theta2 + wedge.theta1) / 2
    x = np.cos(np.deg2rad(angle)) * 0.8
    y = np.sin(np.deg2rad(angle)) * 0.8
    percentage = f'{(size / total) * 100:.1f}%'
    plt.text(x, y, percentage, ha='center', va='center', fontsize=9)

# plt.title('Proportion of Metabolites by Class')
# plt.axis('equal')
plt.tight_layout()
plt.savefig('pie_rev.svg',dpi=600)
plt.show()

# %%
# 데이터 준비
class_counts = df['Class'].value_counts()
labels = [''] * len(class_counts)  # 라벨 제거
sizes = class_counts.values
explode = [0.05] * len(sizes)
colors = sns.color_palette("Set3", n_colors=len(labels))

# 파이차트 그리기
plt.figure(figsize=(2.7, 2.6))
wedges, texts = plt.pie(
    sizes,
    labels=labels,  # 라벨 제거
    startangle=70,
    explode=explode,
    colors=colors,
    wedgeprops={'linewidth': 0.2, 'edgecolor': 'black' }
)

# 퍼센트 수동 배치
total = sum(sizes)
for i, (wedge, size) in enumerate(zip(wedges, sizes)):
    angle = (wedge.theta2 + wedge.theta1) / 2
    x = np.cos(np.deg2rad(angle)) * 0.8
    y = np.sin(np.deg2rad(angle)) * 0.8
    percentage = f'{(size / total) * 100:.1f}%'
    plt.text(x, y, percentage, ha='center', va='center', fontsize=9)

plt.tight_layout()
plt.savefig('pie.png', dpi=600)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 데이터 준비
# ----> 2 class_counts = df['Class'].value_counts()
#       3 labels = [''] * len(class_counts)  # 라벨 제거
#       4 sizes = class_counts.values
#
# NameError: name 'df' is not defined

# %%
# Replace class values that appear only once with "Other"
class_counts_raw = df['Class'].value_counts()
rare_classes = class_counts_raw[class_counts_raw == 1].index
df['Class_modified'] = df['Class'].replace(rare_classes, 'Other')

# Summarize modified class counts
class_counts = df['Class_modified'].value_counts()
labels = class_counts.index
sizes = class_counts.values
explode = [0.03] * len(sizes)
colors = sns.color_palette("Set3", n_colors=len(labels))

class_counts = df['Class_modified'].value_counts()
labels = class_counts.index
sizes = class_counts.values
explode = [0.03] * len(sizes)
colors = sns.color_palette("Set3", n_colors=len(labels))

# Draw pie chart
plt.figure(figsize=(6, 6))
wedges, texts = plt.pie(
    sizes,
    labels=[''] * len(labels),  # Remove labels
    startangle=100,
    explode=explode,
    colors=colors,
    wedgeprops={'linewidth': 0}
)

# Add percentages
total = sum(sizes)
for i, (wedge, size) in enumerate(zip(wedges, sizes)):
    angle = (wedge.theta2 + wedge.theta1) / 2
    x = np.cos(np.deg2rad(angle)) * 0.85
    y = np.sin(np.deg2rad(angle)) * 0.85
    percentage = f'{(size / total) * 100:.1f}%'
    plt.text(x, y, percentage, ha='center', va='center', fontsize=10)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5, 2))
sns.barplot(y=class_counts.index, x=class_counts.values, palette="Set1")
plt.xlabel("Count")
plt.ylabel("Class")
# plt.title("Number of Metabolites by Class (Rare Classes Grouped as 'Other')")
plt.tight_layout()
plt.show()
